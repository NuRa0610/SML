# %% [markdown]
# # **1. Perkenalan Dataset**

# %% [markdown]
# Tahap pertama, Anda harus mencari dan menggunakan dataset dengan ketentuan sebagai berikut:
#
# 1. **Sumber Dataset**:
#    Dataset dapat diperoleh dari berbagai sumber, seperti public repositories (*Kaggle*, *UCI ML Repository*, *Open Data*) atau data primer yang Anda kumpulkan sendiri.

# %% [markdown]
# Semenjak kemunculan internet, media sosial telah menjadi sarana utama bagi banyak orang untuk saling terhubung. Namun, keberhasilan ini tidak terlepas dari tantangan, salah satunya adalah meningkatnya penggunaan bot. Berdasarkan jurnal A global comparison of social media bot and human, sekitar 20% akun di media sosial bukanlah pengguna asli, melainkan bot.
# Bot sering kali dimanfaatkan untuk:
# - menyebarkan iklan yang tidak diinginkan
# - melakukan spam atau interaksi otomatis lainnya
# Masalah ini berdampak pada kenyamanan pengguna, sehingga beberapa platform berupaya untuk:
# - mendeteksi dan membatasi aktivitas bot demi menjaga pengalaman pengguna lainnya
# Penelitian ini bertujuan untuk mendukung upaya tersebut

# %% [markdown]
# Data yang saya gunakan merupakan data dari kaggle oleh juice0lover. yaitu: [Bot vs Human](https://www.kaggle.com/datasets/juice0lover/users-vs-bots-classification/), dataset tersebut berisi karakteristik profile data pada social media rusia yaitu Vk.com. dataset dengan total 5874 baris data dan 60 fitur. Dataset tersebut memiliki data yang tidak lengkap dan duplikat, namun memiliki distribusi yang baik.
#
# **Variabel-variabel pada dataset antara lain adalah:**
#
#  | No | Nama Kolom                   | Tipe Data     | Non-null | Keterangan |
# |----|------------------------------|---------------|----------|------------|
# | 0  | has_domain                   | object        | 5874     | 0 = tidak, 1 = ya |
# | 1  | has_birth_date              | object        | 5874     | 1 = ya, unknown |
# | 2  | has_photo                   | object        | 5874     | 0 = tidak, 1 = ya |
# | 3  | can_post_on_wall            | object        | 5874     | 0 = tidak, 1 = ya |
# | 4  | can_send_message            | object        | 5874     | 0 = tidak, 1 = ya |
# | 5  | has_website                 | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 6  | gender                      | object        | 5874     | 0 = male, 1 = female, unspecified |
# | 7  | has_short_name              | object        | 5874     | 1 = ya |
# | 8  | has_first_name              | object        | 5874     | 1 = ya |
# | 9  | has_last_name               | object        | 5874     | 0 = tidak, 1 = ya |
# | 10 | access_to_closed_profile    | object        | 5874     | 0 = tidak, 1 = ya |
# | 11 | is_profile_closed           | object        | 5874     | 0 = tidak, 1 = ya |
# | 12 | target                      | int64         | 5874     | 0 = manusia, 1 = bot |
# | 13 | has_nickname                | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 14 | has_maiden_name             | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 15 | has_mobile                  | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 16 | all_posts_visible           | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 17 | audio_available             | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 18 | has_interests               | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 19 | has_books                   | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 20 | has_tv                      | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 21 | has_quotes                  | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 22 | has_about                   | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 23 | has_games                   | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 24 | has_movies                  | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 25 | has_activities              | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 26 | has_music                   | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 27 | can_add_as_friend           | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 28 | can_invite_to_group         | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 29 | subscribers_count           | object        | 5874     | jumlah subscriber |
# | 30 | is_blacklisted              | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 31 | has_career                  | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 32 | has_military_service        | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 33 | has_hometown                | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 34 | marital_status              | object        | 5874     | 1–8 = status, 0 = not specified |
# | 35 | has_universities            | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 36 | has_schools                 | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 37 | has_relatives               | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 38 | is_verified                 | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 39 | is_confirmed                | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 40 | has_status                  | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 41 | posts_count                 | float64       | 1391     | jumlah posting |
# | 42 | avg_likes                   | float64       | 1391     | rata-rata likes |
# | 43 | links_ratio                 | float64       | 1391     | rasio penggunaan link |
# | 44 | hashtags_ratio              | float64       | 1391     | rasio penggunaan hashtag |
# | 45 | avg_keywords                | float64       | 1391     | rata-rata jumlah keyword |
# | 46 | avg_text_length             | float64       | 1391     | rata-rata panjang tulisan |
# | 47 | attachments_ratio           | float64       | 1391     | rasio penggunaan lampiran |
# | 48 | avg_comments                | float64       | 1391     | rata-rata komentar |
# | 49 | reposts_ratio               | float64       | 1391     | rasio posting ulang |
# | 50 | ads_ratio                   | float64       | 1391     | rasio iklan |
# | 51 | avg_views                   | float64       | 1391     | rata-rata tayangan |
# | 52 | posting_frequency_days      | float64       | 1391     | frekuensi posting per hari |
# | 53 | phone_numbers_ratio         | float64       | 1391     | rasio nomor telepon |
# | 54 | avg_text_uniqueness         | float64       | 1391     | keunikan rata-rata teks |
# | 55 | city                        | object        | 5874     | kota asal |
# | 56 | has_occupation              | object        | 5874     | 0 = tidak, 1 = ya, unknown |
# | 57 | occupation_type_university  | object        | 5874     | tipe pekerjaan: universitas |
# | 58 | occupation_type_work        | object        | 5874     | tipe pekerjaan: kerja |
# | 59 | has_personal_data           | object        | 5874     | 0 = tidak, 1 = ya, unknown |
#
# - Dataset ini memiliki data kosong dan data duplikasi, sehingga membutuhkan persiaapan atau data preparation.

# %% [markdown]
# # **2. Import Library**

# %% [markdown]
# Pada tahap ini, Anda perlu mengimpor beberapa pustaka (library) Python yang dibutuhkan untuk analisis data dan pembangunan model machine learning atau deep learning.

# %%
#load
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
#prep
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import learning_curve
from sklearn.model_selection import train_test_split
#model
import joblib
from joblib import dump

# %% [markdown]
# # **3. Memuat Dataset**

# %% [markdown]
# Pada tahap ini, Anda perlu memuat dataset ke dalam notebook. Jika dataset dalam format CSV, Anda bisa menggunakan pustaka pandas untuk membacanya. Pastikan untuk mengecek beberapa baris awal dataset untuk memahami strukturnya dan memastikan data telah dimuat dengan benar.
#
# Jika dataset berada di Google Drive, pastikan Anda menghubungkan Google Drive ke Colab terlebih dahulu. Setelah dataset berhasil dimuat, langkah berikutnya adalah memeriksa kesesuaian data dan siap untuk dianalisis lebih lanjut.
#
# Jika dataset berupa unstructured data, silakan sesuaikan dengan format seperti kelas Machine Learning Pengembangan atau Machine Learning Terapan

# %%
#key untuk akses akun kaggle
#from google.colab import files
#files.upload()

# %%
#!mkdir ~/.kaggle
#!mv kaggle.json ~/.kaggle/
#!chmod 600 ~/.kaggle/kaggle.json

# %%
#data yang digunakan adalah user vs bot, dikarenakan masih cukup baru
#!kaggle datasets download -d juice0lover/users-vs-bots-classification
# Out:
# Dataset URL: https://www.kaggle.com/datasets/juice0lover/users-vs-bots-classification
# License(s): MIT
# ...
#   0% 0.00/110k [00:00<?, ?B/s]
# 100% 110k/110k [00:00<00:00, 410MB/s]

# %%
#unzip celana, eh
#!unzip users-vs-bots-classification.zip
# Out:
# Archive:  users-vs-bots-classification.zip
#   inflating: bots_vs_users.csv

# %%
#ubah ke data frame agar lebih mudah di baca
data = pd.read_csv('/content/bots_vs_users.csv')

# %% [markdown]
# # **4. Exploratory Data Analysis (EDA)**
#
# Pada tahap ini, Anda akan melakukan **Exploratory Data Analysis (EDA)** untuk memahami karakteristik dataset.
#
# Tujuan dari EDA adalah untuk memperoleh wawasan awal yang mendalam mengenai data dan menentukan langkah selanjutnya dalam analisis atau pemodelan.

# %% [markdown]
# ## struktur data

# %%
#hal paling dasar pada EDA, yaitu mencari info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5874 entries, 0 to 5873
# Data columns (total 60 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   has_domain                  5874 non-null   object
#  1   has_birth_date              5874 non-null   object
#  2   has_photo                   5874 non-null   object
#  3   can_post_on_wall            5874 non-null   object
#  4   can_send_message            5874 non-null   object
#  5   has_website                 5874 non-null   object
#  6   gender                      5874 non-null   object
#  7   has_short_name              5874 non-null   object
#  8   has_first_name              5874 non-null   object
#  9   has_last_name               5874 non-null   object
#  10  access_to_closed_profile    5874 non-null   object
#  11  is_profile_closed           5874 non-null   object
#  12  target                      5874 non-null   int64
# ...

# %% [markdown]
# * info yang didapat
# * Terdapat 5874 baris data dengan 60 kolom fitur
# * Tipe data terdiri dari 15 numerik (Float, int) dan 45 kategorik (objek)

# %% [markdown]
# ## identifikasi data

# %%
#mengetahui rata rata, minimal, maksimal, secara otomatis, muantap kali
data.describe()
# Out:
#             target  posts_count    avg_likes  links_ratio  hashtags_ratio  \
# count  5874.000000  1391.000000  1391.000000  1391.000000     1391.000000
# mean      0.500000    18.629044    19.552487     0.156463        0.143918
# std       0.500043     4.231994    41.954881     0.202730        0.187085
# min       0.000000     1.000000     0.000000     0.000000        0.000000
# 25%       0.000000    20.000000     0.400000     0.000000        0.000000
# 50%       0.500000    20.000000     7.600000     0.100000        0.050000
# 75%       1.000000    20.000000    26.075000     0.200000        0.200000
# max       1.000000    20.000000   894.900000     1.000000        1.000000
#
#        avg_keywords  avg_text_length  attachments_ratio  avg_comments  \
# count   1391.000000      1391.000000        1391.000000   1391.000000
# mean       7.730661       544.752035           0.895945      0.610812
# std       11.278711       746.728130           0.170084      2.461709
# ...

# %%
# mencari total kolom yang memiliki data kosong
data.isnull().any().sum()
# Out:
# np.int64(14)

# %%
# membuat daftar kolom yang memiliki data kosong
data[data.columns[data.isnull().any()]].isnull().sum()
# Out:
# posts_count               4483
# avg_likes                 4483
# links_ratio               4483
# hashtags_ratio            4483
# avg_keywords              4483
# avg_text_length           4483
# attachments_ratio         4483
# avg_comments              4483
# reposts_ratio             4483
# ads_ratio                 4483
# avg_views                 4483
# posting_frequency_days    4483
# phone_numbers_ratio       4483
# avg_text_uniqueness       4483
# dtype: int64

# %%
#bikin list buat kolom tersebut untuk di proses nantinya~
miss_val = ['posts_count', 'avg_likes', 'links_ratio', 'hashtags_ratio', 'avg_keywords', 'avg_text_length', 'attachments_ratio', 'avg_comments', 'reposts_ratio', 'ads_ratio', 'avg_views', 'posting_frequency_days', 'phone_numbers_ratio', 'avg_text_uniqueness']

# %%
# sum sum sama dengan total
data.isnull().sum().sum()
# Out:
# np.int64(62762)

# %%
# mengetahui doppel granger
data.duplicated().sum()
# Out:
# np.int64(2616)

# %% [markdown]
# * kesimpulan ~
# * Terdapat 14 kolom yang memiliki data kosong
# * Tiap kolom tersebut memiliki 4483 data kosong
# * Total data kosong setiap kolom adalah 62762 data.

# %% [markdown]
# ## distribuis data

# %%
# itung itung data numerik~
numeric_data = data.select_dtypes(include=['int64', 'float64'])
num_vars = len(data.select_dtypes(include=['int64', 'float64']))

# Menentukan baris dan kolom pada subplot

n_cols = 3
n_rows = -(-num_vars // n_cols)  # Ceiling division untuk menentukan jumlah baris

# Membuat subplot
fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, n_rows * 4))

# Flatten axes array untuk memudahkan iterasi
axes = axes.flatten()

# Plot plot di plot
for i, column in enumerate(numeric_data.columns):
    numeric_data[column].hist(ax=axes[i], bins=20, edgecolor='black')
    axes[i].set_title(column)
    axes[i].set_xlabel('Value')
    axes[i].set_ylabel('Frequency')

# Beberes subplot nu teu di anggo (lamun aya)
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# Menyesuaikan layout agar lebih rapi
plt.tight_layout()
plt.show()

# %%
#hubungan antar fitur
sns.pairplot(numeric_data)
plt.show()

# %%
#keterikatan antar fitur, apakah jodoh atau tidak
correlation_matrix = numeric_data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Korelasi Antar Kolom Numerik')
plt.show()

# %%
# mengetahui banyak label target
data['target'].unique()
# Out:
# array([1, 0])

# %%
# distribusi antar kelas
target_ct = data['target'].value_counts()

plt.pie(target_ct, labels=['Manusia 0', 'Bot 1'], autopct='%1.1f%%')
plt.title('Distribusi Target')
plt.show()

# %% [markdown]
# * target 1 adalah adalah bot, dan 0 adalah man-usia (Kata yang punya dataset)
# * distribusi antar kelas seimbang (balanced)

# %% [markdown]
# # **5. Data Preprocessing**

# %% [markdown]
# Pada tahap ini, data preprocessing adalah langkah penting untuk memastikan kualitas data sebelum digunakan dalam model machine learning.
#
# Jika Anda menggunakan data teks, data mentah sering kali mengandung nilai kosong, duplikasi, atau rentang nilai yang tidak konsisten, yang dapat memengaruhi kinerja model. Oleh karena itu, proses ini bertujuan untuk membersihkan dan mempersiapkan data agar analisis berjalan optimal.
#
# Berikut adalah tahapan-tahapan yang bisa dilakukan, tetapi **tidak terbatas** pada:
# 1. Menghapus atau Menangani Data Kosong (Missing Values)
# 2. Menghapus Data Duplikat
# 3. Normalisasi atau Standarisasi Fitur
# 4. Deteksi dan Penanganan Outlier
# 5. Encoding Data Kategorikal
# 6. Binning (Pengelompokan Data)
#
# Cukup sesuaikan dengan karakteristik data yang kamu gunakan yah. Khususnya ketika kami menggunakan data tidak terstruktur.

# %% [markdown]
# ## imputasi data

# %%
'''
karna data kosong berupa numerik jadi pake imputer
imputasi data menggunakan median, katanya lebih robust le
copy data buat jaga jaga ae
'''
data_prep = data.copy()
imp = SimpleImputer(strategy='median')

for name in miss_val:
    data_prep[name] = imp.fit_transform(data_prep[name].values.reshape(-1, 1))

# %%
data_prep.isnull().any().any()
# Out:
# np.False_

# %% [markdown]
# ## duplikat

# %%
data_prep = data_prep.drop_duplicates()

# %% [markdown]
# ## transform data

# %%
# pecah data biar musuhan
y = data_prep[['target']]
X = data_prep.drop(['target'], axis=1)

# %%
#menyiapkan list kolom yang inigin di ubah
categoric_data = data_prep.select_dtypes(include=['object']).columns.tolist()
print("Kolom numerik:", numeric_data.columns.tolist())
print("Kolom kategorik:", categoric_data)
# Out:
# Kolom numerik: ['target', 'posts_count', 'avg_likes', 'links_ratio', 'hashtags_ratio', 'avg_keywords', 'avg_text_length', 'attachments_ratio', 'avg_comments', 'reposts_ratio', 'ads_ratio', 'avg_views', 'posting_frequency_days', 'phone_numbers_ratio', 'avg_text_uniqueness']
# ...

# %%
#hapus target karena itu ya target kelas
numeric_data = numeric_data.drop(columns=['target']).columns.tolist()
print(numeric_data)
# Out:
# ['posts_count', 'avg_likes', 'links_ratio', 'hashtags_ratio', 'avg_keywords', 'avg_text_length', 'attachments_ratio', 'avg_comments', 'reposts_ratio', 'ads_ratio', 'avg_views', 'posting_frequency_days', 'phone_numbers_ratio', 'avg_text_uniqueness']

# %%
#Berrrrubaaaaaah ~ mengubah data kategorik ke numerik, dan numerik dibuat menjadi standar agar lebih seimbang
std = ColumnTransformer(
    [('num_preprocessing', StandardScaler(), numeric_data),
     ('cat_preprocessing', OneHotEncoder(categories='auto'), categoric_data)],
    remainder='passthrough')

X = std.fit_transform(X)

# %% [markdown]
# ## split data

# %%
#cek split yang bagoooos, pake model simpel + learning curvee
tree = DecisionTreeClassifier(max_depth=5, random_state=3)
train_size_abs, train_scores, test_scores = learning_curve(
    tree, X, y, train_sizes=[0.7, 0.8, 0.9]
)
for train_size, cv_train_scores, cv_test_scores in zip(
    train_size_abs, train_scores, test_scores
):
    print(f"{train_size} sampel digunakan untuk data latih")
    print(f"rata rata nilai akurasi latih {cv_train_scores.mean():.2f}")
    print(f"rata rata nilai akurasi tes {cv_test_scores.mean():.2f}")
# Out:
# 3289 sampel digunakan untuk data latih
# rata rata nilai akurasi latih 0.98
# rata rata nilai akurasi tes 0.96
# 3759 sampel digunakan untuk data latih
# rata rata nilai akurasi latih 0.97
# rata rata nilai akurasi tes 0.96
# 4229 sampel digunakan untuk data latih
# rata rata nilai akurasi latih 0.97
# rata rata nilai akurasi tes 0.96

# %% [markdown]
# * Uji data menggunakan base model decision tree mendapat nilai 0.97~0.98 untuk data latih dan 0.96 unutk data tes
# * hasil menunjukan data yang baik dan siap di gunakan
# * karna ga ada perbedaan jauh, jadi ambil 70:30 aja paling tinggi

# %%
# encode label, karna kadang ga kebaca ama model
le = LabelEncoder()
y_le = le.fit_transform(y.values.ravel())

# %%
#split data 70:30 berdasarkan hasil curve di atas
from sklearn.model_selection import train_test_split

train_X, test_X, train_y, test_y = train_test_split(
    X, y_le, test_size=0.3, shuffle = True , random_state=42)
